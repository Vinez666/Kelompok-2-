# %%
#import library yang akan digunakan
import matplotlib.pyplot as plt 
import pandas as pd

# %%
#membaca data
data = pd.read_csv("Keterlibatan Perempuan di Parlemen, 2022.csv")
data.head(553)
# Out:
#     Provinsi / Kabupaten / Kota   2022  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                          ACEH  11.11         NaN         NaN         NaN
# 1                      SIMEULUE     20         NaN         NaN         NaN
# 2                  ACEH SINGKIL     12         NaN         NaN         NaN
# 3                  ACEH SELATAN     10         NaN         NaN         NaN
# 4                 ACEH TENGGARA     10         NaN         NaN         NaN
# ..                          ...    ...         ...         ...         ...
# 548                      PUNCAK      4         NaN         NaN         NaN
# 549                     DOGIYAI      -         NaN         NaN         NaN
# 550                  INTAN JAYA      -         NaN         NaN         NaN
# 551                      DEIYAI      -         NaN         NaN         NaN
# 552               KOTA JAYAPURA   22.5         NaN         NaN         NaN
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# ...

# %%
# creating a rank column and passing the returned rank series 
data["Rank"] = data["Provinsi / Kabupaten / Kota"].rank() 
data.head()
# Out:
#   Provinsi / Kabupaten / Kota   2022  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                        ACEH  11.11         NaN         NaN         NaN
# 1                    SIMEULUE     20         NaN         NaN         NaN
# 2                ACEH SINGKIL     12         NaN         NaN         NaN
# 3                ACEH SELATAN     10         NaN         NaN         NaN
# 4               ACEH TENGGARA     10         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8   Rank
# 0         NaN         NaN         NaN         NaN    1.0
# 1         NaN         NaN         NaN         NaN  479.0
# 2         NaN         NaN         NaN         NaN    7.0
# 3         NaN         NaN         NaN         NaN    6.0
# 4         NaN         NaN         NaN         NaN   10.0

# %%
# sorting w.r.t name column 
data.sort_values("Provinsi / Kabupaten / Kota", inplace = True) 
data.head(4)
# Out:
#    Provinsi / Kabupaten / Kota   2022  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                         ACEH  11.11         NaN         NaN         NaN
# 7                   ACEH BARAT      8         NaN         NaN         NaN
# 12             ACEH BARAT DAYA      4         NaN         NaN         NaN
# 8                   ACEH BESAR   2.86         NaN         NaN         NaN
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Rank
# 0          NaN         NaN         NaN         NaN   1.0
# 7          NaN         NaN         NaN         NaN   2.0
# 12         NaN         NaN         NaN         NaN   3.0
# 8          NaN         NaN         NaN         NaN   4.0

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
Kabupaten = ['Aceh', 'Aceh Barat', 'Aceh Barat Daya', 'Aceh Besar']
Nilai = [11.11,8,4,2.86]
ax.pie(Nilai,labels=Kabupaten,autopct='%1.2f%%')
plt.show()
